# %% [markdown]
# <a href="https://colab.research.google.com/github/Krishnavenia68/assignment/blob/main/Analyzing_the_Impact_of_Gaming_Behavior_on_Academic_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-53ee03ca-e028-4060-ba15-18c07ea11f61" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-53ee03ca-e028-4060-ba15-18c07ea11f61">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("Gaming_Academic_Performance.csv")
df.head()
# Out:
#    student_id  age  gender  gaming_hours  study_hours  sleep_hours  \
# 0           1   22    Male          7.23         8.78         6.96
# 1           2   19    Male          0.07         8.72         7.63
# 2           3   23  Female          1.73         9.56         4.40
# 3           4   20  Female          6.62         1.68         7.83
# 4           5   22  Female          5.36         5.83         5.55
#
#    attendance gaming_genre  social_activity  device_usage  reaction_time_ms  \
# 0       91.44          FPS             3.25          9.36            235.84
# 1       63.63       Casual             1.02          3.21            328.71
# 2       83.26       Casual             3.46          5.56            313.61
# 3       75.04          RPG             1.46         11.78            241.84
# 4       65.57          FPS             1.01          8.23            249.31
#
#    addiction_score stress_level     grades
# 0            14.69          Low  86.459555
# ...

# %%
df.tail()
# Out:
#       student_id  age  gender  gaming_hours  study_hours  sleep_hours  \
# 7995        7996   24    Male          6.33         5.09         4.83
# 7996        7997   22  Female          5.77         6.09         6.23
# 7997        7998   20    Male          2.87         8.51         8.62
# 7998        7999   22  Female          0.98         2.99         7.29
# 7999        8000   18  Female          1.73         8.75         7.65
#
#       attendance gaming_genre  social_activity  device_usage  \
# 7995       63.74          FPS             4.11          9.96
# 7996       84.37          FPS             3.42         11.19
# 7997       67.30          FPS             2.36          6.40
# 7998       61.13          FPS             2.02          4.57
# 7999       78.68          RPG             4.03          6.33
#
#       reaction_time_ms  addiction_score stress_level  grades
# 7995            231.33            11.14          Low   35.11
# ...

# %%
df.describe()
# Out:
#        student_id          age  gaming_hours  study_hours  sleep_hours  \
# count  8000.00000  8000.000000   8000.000000  8000.000000  8000.000000
# mean   4000.50000    19.983625      4.085773     5.460581     6.493453
# std    2309.54541     2.587072      2.308801     2.575787     1.442656
# min       1.00000    16.000000      0.000000     1.000000     4.000000
# 25%    2000.75000    18.000000      2.130000     3.240000     5.240000
# 50%    4000.50000    20.000000      4.130000     5.460000     6.505000
# 75%    6000.25000    22.000000      6.060000     7.660000     7.730000
# max    8000.00000    24.000000      8.000000    10.000000     9.000000
#
#         attendance  social_activity  device_usage  reaction_time_ms  \
# count  8000.000000      8000.000000   8000.000000       8000.000000
# mean     79.886525         2.507790      7.586315        271.105839
# std      11.580419         1.441128      2.710035         29.440675
# ...

# %%
df.describe(include=("all"))
# Out:
#         student_id          age gender  gaming_hours  study_hours  \
# count   8000.00000  8000.000000   8000   8000.000000  8000.000000
# unique         NaN          NaN      3           NaN          NaN
# top            NaN          NaN   Male           NaN          NaN
# freq           NaN          NaN   3904           NaN          NaN
# mean    4000.50000    19.983625    NaN      4.085773     5.460581
# std     2309.54541     2.587072    NaN      2.308801     2.575787
# min        1.00000    16.000000    NaN      0.000000     1.000000
# 25%     2000.75000    18.000000    NaN      2.130000     3.240000
# 50%     4000.50000    20.000000    NaN      4.130000     5.460000
# 75%     6000.25000    22.000000    NaN      6.060000     7.660000
# max     8000.00000    24.000000    NaN      8.000000    10.000000
#
#         sleep_hours   attendance gaming_genre  social_activity  device_usage  \
# count   8000.000000  8000.000000         8000      8000.000000   8000.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   student_id        8000 non-null   int64
#  1   age               8000 non-null   int64
#  2   gender            8000 non-null   object
#  3   gaming_hours      8000 non-null   float64
#  4   study_hours       8000 non-null   float64
#  5   sleep_hours       8000 non-null   float64
#  6   attendance        8000 non-null   float64
#  7   gaming_genre      8000 non-null   object
#  8   social_activity   8000 non-null   float64
#  9   device_usage      8000 non-null   float64
#  10  reaction_time_ms  8000 non-null   float64
#  11  addiction_score   8000 non-null   float64
#  12  stress_level      8000 non-null   object
#  13  grades            8000 non-null   float64
# dtypes: float64(9), int64(2), object(3)
# memory usage: 875.1+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#       student_id  age  gender  gaming_hours  study_hours  sleep_hours  \
# 0              1   22    Male          7.23         8.78         6.96
# 1              2   19    Male          0.07         8.72         7.63
# 2              3   23  Female          1.73         9.56         4.40
# 3              4   20  Female          6.62         1.68         7.83
# 4              5   22  Female          5.36         5.83         5.55
# ...          ...  ...     ...           ...          ...          ...
# 7995        7996   24    Male          6.33         5.09         4.83
# 7996        7997   22  Female          5.77         6.09         6.23
# 7997        7998   20    Male          2.87         8.51         8.62
# 7998        7999   22  Female          0.98         2.99         7.29
# 7999        8000   18  Female          1.73         8.75         7.65
#
#       attendance gaming_genre  social_activity  device_usage  \
# 0          91.44          FPS             3.25          9.36
# ...

# %%
df.isnull().sum()
# Out:
# student_id          0
# age                 0
# gender              0
# gaming_hours        0
# study_hours         0
# sleep_hours         0
# attendance          0
# gaming_genre        0
# social_activity     0
# device_usage        0
# reaction_time_ms    0
# addiction_score     0
# stress_level        0
# grades              0
# dtype: int64

# %%
df.rename(columns={"reaction_time_ms":"reaction_time"})
# Out:
#       student_id  age  gender  gaming_hours  study_hours  sleep_hours  \
# 0              1   22    Male          7.23         8.78         6.96
# 1              2   19    Male          0.07         8.72         7.63
# 2              3   23  Female          1.73         9.56         4.40
# 3              4   20  Female          6.62         1.68         7.83
# 4              5   22  Female          5.36         5.83         5.55
# ...          ...  ...     ...           ...          ...          ...
# 7995        7996   24    Male          6.33         5.09         4.83
# 7996        7997   22  Female          5.77         6.09         6.23
# 7997        7998   20    Male          2.87         8.51         8.62
# 7998        7999   22  Female          0.98         2.99         7.29
# 7999        8000   18  Female          1.73         8.75         7.65
#
#       attendance gaming_genre  social_activity  device_usage  reaction_time  \
# ...

# %%
print(df.columns)
# Out:
# Index(['student_id', 'age', 'gender', 'gaming_hours', 'study_hours',
#        'sleep_hours', 'attendance', 'gaming_genre', 'social_activity',
#        'device_usage', 'reaction_time_ms', 'addiction_score', 'stress_level',
#        'grades'],
#       dtype='object')

# %%
df.shape
# Out:
# (8000, 14)

# %%
df.dropna()
# Out:
#       student_id  age  gender  gaming_hours  study_hours  sleep_hours  \
# 0              1   22    Male          7.23         8.78         6.96
# 1              2   19    Male          0.07         8.72         7.63
# 2              3   23  Female          1.73         9.56         4.40
# 3              4   20  Female          6.62         1.68         7.83
# 4              5   22  Female          5.36         5.83         5.55
# ...          ...  ...     ...           ...          ...          ...
# 7995        7996   24    Male          6.33         5.09         4.83
# 7996        7997   22  Female          5.77         6.09         6.23
# 7997        7998   20    Male          2.87         8.51         8.62
# 7998        7999   22  Female          0.98         2.99         7.29
# 7999        8000   18  Female          1.73         8.75         7.65
#
#       attendance gaming_genre  social_activity  device_usage  \
# 0          91.44          FPS             3.25          9.36
# ...

# %%
df[df["attendance"]>70]
# Out:
#       student_id  age  gender  gaming_hours  study_hours  sleep_hours  \
# 0              1   22    Male          7.23         8.78         6.96
# 2              3   23  Female          1.73         9.56         4.40
# 3              4   20  Female          6.62         1.68         7.83
# 6              7   22  Female          0.46         7.40         6.55
# 8              9   20  Female          4.55         7.93         8.76
# ...          ...  ...     ...           ...          ...          ...
# 7988        7989   21    Male          5.36         4.10         5.90
# 7991        7992   22  Female          1.22         9.14         4.34
# 7993        7994   19  Female          5.25         9.36         7.95
# 7996        7997   22  Female          5.77         6.09         6.23
# 7999        8000   18  Female          1.73         8.75         7.65
#
#       attendance gaming_genre  social_activity  device_usage  \
# 0          91.44          FPS             3.25          9.36
# ...

# %%
df[df["gender"]=="femal"]
# Out:
# Empty DataFrame
# Columns: [student_id, age, gender, gaming_hours, study_hours, sleep_hours, attendance, gaming_genre, social_activity, device_usage, reaction_time_ms, addiction_score, stress_level, grades]
# Index: []

# %%
df.sort_values("age")
# Out:
#       student_id  age  gender  gaming_hours  study_hours  sleep_hours  \
# 7965        7966   16    Male          4.74         9.76         6.65
# 7960        7961   16  Female          3.20         2.43         4.89
# 2700        2701   16    Male          0.52         4.03         6.70
# 2697        2698   16  Female          2.14         8.97         6.08
# 6245        6246   16   Other          3.25         1.53         5.56
# ...          ...  ...     ...           ...          ...          ...
# 5373        5374   24    Male          2.54         4.69         4.31
# 5285        5286   24    Male          3.33         9.94         5.19
# 5305        5306   24  Female          7.59         2.35         8.57
# 5310        5311   24    Male          4.76         4.13         5.78
# 7995        7996   24    Male          6.33         5.09         4.83
#
#       attendance gaming_genre  social_activity  device_usage  \
# 7965       99.29       Casual             1.55          9.98
# ...

# %%
import matplotlib.pyplot as plt
df["sleep_hours"].hist()
# Out:
# <Axes: >

# %%
df["attendance"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='attendance'>

# %%
df["study_hours"].value_counts().plot(kind="pie")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_12301/4142477371.py in <cell line: 0>()
#       1 df["study_hours"].value_counts().plot(kind="pie")
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt
df["study_hours"].value_counts().plot(kind="pie")
plt.show()
